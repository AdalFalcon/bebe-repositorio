# %%
lista = "Carrito de compras\n"

Productos_diponibles = ["Pan", "Jamón", "Crema", "Mayonesa", "Lechuga"]

# pan = 1
# jamón =2
# crema = 3
# mayonesa = 4
# lechuga = 5

print(lista)
print("Estos son los productos disponibles en la tienda\n",Productos_diponibles, '\n')
print("total",len(Productos_diponibles),'\n')

Productos_diponibles.append("Tocino")
Productos_diponibles.append("Refresco")
Productos_diponibles.append("Chiles")

# Tocino = 6
# Refresco = 7
# Chiles = 8

print("Se agregaron nuevo productos a la tienda\n",Productos_diponibles)
print("total",len(Productos_diponibles),'\n')

En_carrito_1 = [[2, 1], [3, 8], [1,5]]
En_carrito_2 = [[1,3], [2,6], [5,4]]



print('Tu carrito tiene',len(En_carrito_1),'productos''\n')
print(En_carrito_1, '\n')
print('Tu carrito tiene',len(En_carrito_2),'productos''\n')
print(En_carrito_2, '\n')

Mi_carrito_de_compras = eval(input("Ingresa tu carrito de compras: "))
print("\n\nTu carrito es:")
if type(my_shopping_cart) == list:
    if type(my_shopping_cart[0]) == list:
        for element in my_shopping_cart:
            product = ""
            if element[1] == 1:
                product = "Pan"
            elif element[1] == 2:
                product = "Jamón"
            elif element[1] == 3:
                product = "Crema"
            elif element[1] == 4:
                product = "Mayonesa"
            elif element[1] == 5:
                product = "Lechuga"
            elif element[1] == 6:
                product = "Tocino"
            elif element[1] == 7:
                product = "Refresco"
            elif element[1] == 8:
                product = "Chiles"
            else:
                product = "Producto Desconocido"
            print("{} {}".format(element[0], product))
    else:
        print("Formato incorrecto, debes ingresar una lista de listas")
else:
    print("Formato incorrecto, debes ingresar una lista de listas")
